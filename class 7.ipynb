# %%
user = int(input("enter your shopping amount"))

if user >= 5000:
    print("discound valid")
else:
   print ("not valid")
# Out:
# enter your shopping amount 3000
# not valid

# %%
a = int(input("enter your 1 no"))
b = int(input("enter your 2 no"))
c = input("enter your operator")

if c=="+" :
    print (a+b)
elif c == "-" :
    print (a-b)
elif c == "*" :
    print (a*b)
elif c == "/" :
    print (a/b)

else:
    print ("invalid")
# Out:
# enter your 1 no 1
# enter your 2 no 2
# enter your operator @
# invalid
